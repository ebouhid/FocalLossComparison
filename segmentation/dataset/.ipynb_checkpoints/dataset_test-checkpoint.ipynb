# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from dataset import XinguDataset

# %%
# getting Fold 1 dataset info
train_regions = [1, 2, 6, 7, 8, 9, 10]
test_regions = [3, 4]
train_ds = XinguDataset('./scenes_allbands_ndvi',
                                './truth_masks',
                                range(1,4),
                                train_regions,
                                256,
                                64,
                                transforms=True)
test_ds = XinguDataset('./scenes_allbands_ndvi',
                               './truth_masks',
                               [4, 3, 2], test_regions,
                               256, 256)

# %%
image, mask = test_ds[0]
image = image.transpose(1, 2, 0)
plt.imshow(image)

# %%
test_ds = XinguDataset('./scenes_pca',
                               './truth_masks',
                               range(1, 4), test_regions,
                               256, 256)
image, mask = test_ds[0]
image = image.transpose(1, 2, 0)
plt.imshow(image)

# %%
print(f'Train ds: {len(train_ds)}')
print(f'Test ds: {len(test_ds)}')
# Out:
# Train ds: 9432
# Test ds: 18

# %%
ds_no_aug = XinguDataset('scenes_allbands_ndvi/', 'truth_masks', [4,6,7], range(1, 11), 256, 256)
ds_aug = XinguDataset('scenes_allbands_ndvi/', 'truth_masks', [8], range(1, 11), 256, 256, True)

# %%
print(f'ds_no_aug: {len(ds_no_aug)} samples')
print(f'ds_aug: {len(ds_aug)} samples')
# Out:
# ds_no_aug: 124 samples
# ds_aug: 992 samples

# %%
image, mask = ds_aug.__getitem__(11)
print(f'mask shape: {mask.shape}')
# Out:
# mask shape: (1, 256, 256, 4)

# %%
np.unique(mask)
# Out:
# array([0., 1.], dtype=float32)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].imshow(image.transpose(1, 2, 0))
ax[1].imshow(np.argmax(mask, axis=-1).squeeze(), cmap='gray')

# %%
image, mask = ds_aug.__getitem__(8)
print(f'mask shape: {mask.shape}')
# Out:
# mask shape: (1, 256, 256, 4)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].imshow(image.transpose(1, 2, 0))
ax[1].imshow(mask.squeeze())
